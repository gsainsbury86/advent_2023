# %%
import requests

year = 2023
day = 14

url = f"https://adventofcode.com/{year}/day/{day}/input"

with open("cookie.txt", "r") as file:
    session = file.read()

headers = {"cookie": f"session={session}"}

with open(f"inputs/day_{str(day).zfill(2)}_input.txt", "wb") as file:
    file.write(requests.get(url, headers=headers).content)

lines = [x.strip() for x in open(f"inputs/day_{str(day).zfill(2)}_input.txt", "r")]
print(lines[:5])
# Out:
# ['......#.O#O.##...O.....#...#..##...OO#.OO.......O.##....O.......O..#.#..O.O...O#O.O....#.O..OO..O.O.', '.##.##OO..#.#O..##..OOO#..O.....O.O...#.........#.......#.O#.O..O...O..OO#O..O....#..O..#OO.O..O....', 'O.....#..#..O.#OOO.OO..O..#..#O.....O...#.O..#..#O#.........#.#.....###.#.#.O...#.#.O......O..OO..#.', 'O..#.#..#........O......O.OO#.OO..O.O...O.O.......O...O......#....O##.#.OO.#..#.O#O.O.#.#.O...#...O.', '...O........#.O.....#O.....OO#.#.##O...#..OO...#.O.#.##.OO...#.O.#O..O......#..#.....#..#..O#..#....']

# %%
test = """O....#....
O.OO#....#
.....##...
OO.#O....O
.O.....O#.
O.#..O.#.#
..O..#O..O
.......O..
#....###..
#OO..#....""".split("\n")

source = lines

source = [[x for x in y] for y in source]

rock_moved = True
while rock_moved:
    rock_moved = False
    for r, row in enumerate(source):
        if r == 0:
            continue
        for c, col in enumerate(row):
            if col == 'O' and source[r-1][c] == '.':
                source[r][c] = '.'
                source[r-1][c] = 'O'
                rock_moved = True
                
            
            
print(source)

for r in range(len(source)):
    line = ""
    for c in range(len(source[0])):
        line += source[r][c]
    print(line)

score = 0
for r, row in enumerate(source):
    for c, col in enumerate(row):
        if col == 'O':
            score += len(source) - r
            
print(score)
# Out:
# [['O', '.', '.', '.', '.', '.', '#', 'O', 'O', '#', 'O', 'O', '#', '#', '.', 'O', '.', 'O', 'O', 'O', 'O', 'O', 'O', '#', 'O', '.', 'O', '#', '.', '.', '#', '#', 'O', '.', 'O', 'O', 'O', '#', '.', 'O', 'O', 'O', 'O', 'O', 'O', '.', '.', '.', 'O', 'O', '#', '#', 'O', '.', 'O', '.', 'O', 'O', 'O', '.', '.', 'O', '.', 'O', 'O', '.', 'O', '#', 'O', '#', '.', 'O', 'O', '.', 'O', '.', 'O', 'O', 'O', '#', 'O', '.', 'O', '.', 'O', 'O', '.', '#', '.', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', '.', 'O', 'O'], ['O', '#', '#', '.', '#', '#', 'O', 'O', '.', '.', '#', '.', '#', 'O', '.', '.', '#', '#', 'O', 'O', 'O', 'O', 'O', '#', '.', '.', '.', 'O', '.', '.', 'O', 'O', 'O', '.', 'O', 'O', 'O', 'O', '#', '.', '.', 'O', 'O', '.', 'O', '.', '.', '.', '#', 'O', '.', '.', 'O', '.', '.', '.', '#', 'O', '.', '#', '.', '.', '.', '.', 'O', '.', 'O', '.', '.', '.', '.', 'O', 'O', '#', 'O', '.', '.', 'O', '.', '.', '.', '.', '#', '.', 'O', '.', '.', 'O', '#', 'O', 'O', 'O', 'O', 'O', '.', 'O', 'O', '.', '.',
# ...

# %%
# import numpy as np
from tqdm import tqdm

test = """O....#....
O.OO#....#
.....##...
OO.#O....O
.O.....O#.
O.#..O.#.#
..O..#O..O
.......O..
#....###..
#OO..#....""".split("\n")

source = lines

source = tuple([tuple([x for x in y]) for y in source])



def tilt(inp):
    new = [[x for x in y] for y in inp]
    rock_moved = True
    while rock_moved:
        rock_moved = False
        for r, row in enumerate(new):
            if r == 0:
                continue
            for c, col in enumerate(row):
                if col == 'O' and new[r-1][c] == '.':
                    new[r][c] = '.'
                    new[r-1][c] = 'O'
                    rock_moved = True
    
    return new
                    

    
hashes = []
    
MAX = 1000000000
new = source
jumped = False
i = 0 
while i < MAX:
    
    for s in range(0,4):
        new = tilt(new)
        new = np.rot90(new,k=3)
        

    hsh = hash(tuple([tuple([x for x in y]) for y in new]))
    
    #    print(hsh)
    if hsh in hashes and not jumped:
        print(f"seen hsh before at i == {hashes.index(hsh)}. can jump forward.")
        cycle_length = i-hashes.index(hsh)
        print(cycle_length)
        num_cycles = (MAX - i )// cycle_length
        print(num_cycles)
        i+=(num_cycles * cycle_length) 
        print(i)
        jumped = True
    hashes.append(hsh)

    i += 1


print()

score = 0
for r, row in enumerate(new):
    for c, col in enumerate(row):
        if col == 'O':
            score += len(source) - r

print(score)
            
# print(source)
new = np.rot90(new,k=2)
for r in range(len(new)):
    line = ""
    for c in range(len(new[0])):
        line += new[r][c]
    print(line)
# Out:
# seen hsh before at i == 93. can jump forward.
# 44
# 22727269
# 999999973
#
# 101010
# O.##O#OO....#O.#O#.##O.#O#OO....#.#OOOOOOO...#OO.#O..#...#OO..#OOOO.#.##O#O..#OOOO...#OOOO...#OOOOO.
# OOOO..#O....#OOOOO.....#OOO.............#OOO........#OO...#..#OO...#..#OO........#O..#O##.#OOOO.....
# OO.#O..#..#OOOO...........#.......##OO..#O.#OOO...............###.....#O.........#...#OOOOOO...#.#..
# O.....#OOO........#O.........##.#OOOOO....#.......#O...##....#OO...##.....#O...##O.........##OO..#.#
# ...#..#.##O..........#O........#.#.#O...#OO#OO..............#OO#OOOO.............#......##OOO.......
# ..##.#OO.#.##.....#..#........#OO.......#...##.....#O....##OOO...##O...........#O.#....#OO..#O....#O
# #.#....#O..#...#O..#OOO....................#O...#O....#O.#OOO........#O.........#O.#...#OOO....#.#OO
# ...#........#O..#OO......#.....#O.........#...........#O.#OO.....#.#..##.......#.#.#O......#OOOO....
# ...

# %%
1000000000/4
# Out:
# 250000000.0
