n=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7"""

source = test
source = lines[0]

# source = "HASH"

substrings = source.split(",")

hshs = []
for substring in substrings:
    hsh = 0
    for c in substring:
        val = ord(c)
        hsh += val
        hsh *= 17
        hsh = hsh % 256
    hshs.append(hsh)

print(hshs)
print(sum(hshs))
# Out:
# [248, 95, 7, 130, 217, 59, 183, 254, 179, 75, 137, 220, 128, 21, 9, 5, 249, 109, 151, 220, 41, 48, 225, 92, 95, 244, 195, 110, 241, 206, 67, 107, 123, 30, 43, 106, 201, 217, 131, 149, 226, 131, 82, 115, 138, 147, 161, 184, 200, 86, 102, 14, 195, 156, 86, 169, 84, 243, 126, 82, 195, 53, 72, 162, 8, 56, 225, 147, 233, 152, 75, 148, 125, 255, 191, 120, 157, 61, 37, 96, 46, 0, 59, 96, 10, 216, 0, 229, 27, 107, 134, 91, 196, 205, 125, 141, 205, 145, 247, 208, 211, 172, 81, 251, 26, 91, 229, 120, 207, 142, 138, 132, 145, 128, 96, 113, 223, 4, 217, 142, 138, 196, 168, 141, 233, 9, 27, 112, 225, 246, 142, 235, 12, 232, 70, 165, 152, 215, 184, 209, 117, 62, 79, 246, 16, 166, 136, 191, 192, 206, 144, 251, 245, 13, 129, 53, 185, 37, 100, 106, 188, 189, 185, 144, 158, 253, 132, 55, 163, 13, 30, 55, 71, 8, 118, 31, 63, 73, 186, 145, 192, 84, 148, 153, 180, 151, 155, 18, 236, 132, 44, 67, 242, 46, 61, 1, 33, 5, 171, 14, 184, 237, 251, 36, 235, 131, 157, 184, 146, 85, 191, 194, 13, 176, 225, 26, 14
# ...

# %%
test = """rn=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7"""

source = test
source = lines[0]

# source = "HASH"

substrings = source.split(",")

hshs = []
boxes = [[] for x in range(256)]
for substring in substrings:
    label = substring[:-1]
    op = substring[-1]

    hsh = 0
    for c in label:
        val = ord(c)
        hsh += val
        hsh *= 17
        hsh = hsh % 256

    if op == "-":
        for i in boxes[hsh]:
            value, lens = i
            if value == label:
                boxes[hsh].remove(i)
                break
    else:
        label, old = substring.split("=")

        hsh = 0
        for c in label:
            val = ord(c)
            hsh += val
            hsh *= 17
            hsh = hsh % 256

        for ind, i in enumerate(boxes[hsh]):
            value, lens = i
            if value == label:
                print("here")
                boxes[hsh][ind] = (label, old)
                break
        else:
            boxes[hsh].append((label, old))

    # hshs.append(hsh)

    print(boxes[0], boxes[1], boxes[3])

score = 0
for boxind, box in enumerate(boxes):
    for slotind, slot in enumerate(box):
        lens, focus = slot
        power = (boxind + 1) * (slotind + 1) * int(focus)

        print(power)
        score += power

print(score)
# Out:
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# here
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# [('mznxrq', '1')] [] []
# ...
