# %%
import requests

year = 2023
day = 7

url = f"https://adventofcode.com/{year}/day/{day}/input"

with open("cookie.txt", "r") as file:
    session = file.read()

headers = {"cookie": f"session={session}"}

with open(f"inputs/day_{str(day).zfill(2)}_input.txt", "wb") as file:
    file.write(requests.get(url, headers=headers).content)

lines = [x.strip() for x in open(f"inputs/day_{str(day).zfill(2)}_input.txt", "r")]
print(lines[:5])
# Out:
# ['J2566 131', 'K7KK7 272', '2K222 74', '44T55 467', '33433 226']

# %%
test = """32T3K 765
T55J5 684
KK677 28
KTJJT 220
QQQJA 483""".split(
    "\n"
)

source = lines
pics = ["T", "J", "Q", "K", "A"]

poss = [str(x) for x in range(2, 10)] + pics


def score(hand):
    cc_1 = {c: list(hand).count(c) for c in poss if list(hand).count(c) > 0}

    # 7 ranks, 13 values

    rank = ""

    if 5 in cc_1.values():
        rank = "7"
    elif 4 in cc_1.values():
        rank = "6"
    elif 3 in cc_1.values() and 2 in cc_1.values():
        rank = "5"
    elif 3 in cc_1.values():
        rank = "4"
    elif list(cc_1.values()).count(2) == 2:
        rank = "3"
    elif 2 in cc_1.values():
        rank = "2"
    else:
        rank = "1"

    for h in hand:
        if h in pics:
            rank += ["A", "B", "C", "D", "E"][pics.index(h)]
        else:
            rank += h
    return rank


scores = []
for hand in source:
    cards, bid = hand.split()

    scores.append((cards, bid, score(cards)))

scores.sort(key=lambda x: x[2])
scores = [x for x in reversed(scores)]

# print(scores)

winnings = [(len(scores) - x) * int(scores[x][1]) for x in range(len(scores))]
# print(winnings)
print(sum(winnings))

# 251232425 wrong
# Out:
# 250602641

# %%
test = """32T3K 765
T55J5 684
KK677 28
KTJJT 220
QQQJA 483""".split(
    "\n"
)


# JOKES

source = lines
pics = ["T", "Q", "K", "A"]

poss = [str(x) for x in range(2, 10)] + pics


def score(hand):
    cc_1 = {c: list(hand).count(c) for c in poss if list(hand).count(c) > 0}

    rank = ""

    if 5 in cc_1.values():
        rank = "7"
    elif 4 in cc_1.values():
        rank = "6"
    elif 3 in cc_1.values() and 2 in cc_1.values():
        rank = "5"
    elif 3 in cc_1.values():
        rank = "4"
    elif list(cc_1.values()).count(2) == 2:
        rank = "3"
    elif 2 in cc_1.values():
        rank = "2"
    else:
        rank = "1"

    for h in hand:
        if h in pics:
            rank += ["A", "B", "C", "D"][pics.index(h)]
        elif h == "J":
            rank += "0"
        else:
            rank += h
    return rank


from time import sleep

scores = []
for hand in source:
    cards, bid = hand.split()

    hands_to_test = [cards]
    building = True
    while building:
        next_test = []
        for htt in hands_to_test:
            if "J" in htt:
                for i in [x for x in range(2, 10)] + pics:
                    this_hand = htt.replace("J", str(i), 1)
                    next_test.append(this_hand)

        hands_to_test = next_test

        building = False
        for htt in hands_to_test:
            if "J" in htt:
                building = True

    best_hand = cards
    best_score = "0"

    for this_hand in hands_to_test:
        this_score = score(this_hand)
        if this_score > best_score:
            best_score = this_score
            best_hand = this_hand

    scores.append((cards, bid, score(best_hand), score(cards)))

scores.sort(key=lambda x: x[2][0] + x[3][1:])
scores = [x for x in reversed(scores)]

print(scores)

winnings = [(len(scores) - x) * int(scores[x][1]) for x in range(len(scores))]
print(winnings)
print(sum(winnings))
# 251232425 wrong
# Out:
# [('AAJAA', '978', '7DDDDD', '6DD0DD'), ('KJKJK', '410', '7CCCCC', '4C0C0C'), ('QQJQQ', '216', '7BBBBB', '6BB0BB'), ('TTTTJ', '357', '7AAAAA', '6AAAA0'), ('9999J', '842', '799999', '699990'), ('9J99J', '974', '799999', '490990'), ('88J88', '751', '788888', '688088'), ('8JJJJ', '771', '788888', '180000'), ('77J77', '603', '777777', '677077'), ('66J66', '536', '766666', '666066'), ('55J55', '248', '755555', '655055'), ('44J4J', '745', '744444', '444040'), ('4J444', '789', '744444', '640444'), ('3333J', '572', '733333', '633330'), ('2222J', '233', '722222', '622220'), ('2JJ22', '303', '722222', '420022'), ('JKKKK', '44', '7CCCCC', '60CCCC'), ('JTJTT', '758', '7AAAAA', '40A0AA'), ('J8J88', '795', '788888', '408088'), ('J7JJ7', '512', '777777', '207007'), ('J5J55', '485', '755555', '405055'), ('J3J33', '555', '733333', '403033'), ('JJQQQ', '154', '7BBBBB', '400BBB'), ('JJJJJ', '847', '7DDDDD', '100000'), ('AAA6J', '373', '6DDD6D', '4DDD60'), ('AAKAA', '256', '6DDCDD', '6DDCDD'), ('AATAA', 
# ...
