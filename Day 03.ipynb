# %%
import requests

year = 2023
day = 3

url = f"https://adventofcode.com/{year}/day/{day}/input"

with open("cookie.txt", "r") as file:
    session = file.read()

headers = {"cookie": f"session={session}"}

with open(f"inputs/day_{str(day).zfill(2)}_input.txt", "wb") as file:
    file.write(requests.get(url, headers=headers).content)

lines = [x.strip() for x in open(f"inputs/day_{str(day).zfill(2)}_input.txt", "r")]
print(lines[:5])
# Out:
# ['...........................775.651...............887....79...946...921...493.....942..942.....151....155....................................', '......240...................*.....-......................$..*...................*.......%.....+....................956.549.*290.......834...', '.485...+............437......906......%..608.805.725..72.....242....745..61......440................................*..*.........515...*....', '..........917.......&....146........790.....*......*....*..........*.....*...............207*......................796..116......../...924..', '722...323.-................./...410.............72..748.442............384.708...............849..%............................470..........']

# %%
test = """
467..114..
...*......
..35..633.
......#...
617*......
.....+.58.
..592.....
......755.
...$.*....
.664.598..""".split(
    "\n"
)[
    1:
]

import re

# lines2 = [[x for x in re.sub('[^0-9a-zA-Z]+', '*', line).split('*') if x != ''] for line in lines]

# lines2 = [[x for x in re.sub('[0-9.]+', '', line) if x != ''] for line in lines]
#
# lines2 = sum(lines2, [])
# print(len(lines2))


digits = []
symbols = {}
digit_str = ""
for l, line in enumerate(lines):
    in_digit = False
    for c, char in enumerate(line):
        if char.isdigit():
            digit_str += char
            if not in_digit:
                in_digit = True
                start = c
        else:
            if in_digit:
                end = c
                digits.append([l, [start, end], digit_str])
                digit_str = ""
            in_digit = False
            if char != ".":
                symbols[(l, c)] = char
    if in_digit:
        end = c
        digits.append([l, [start, end], digit_str])
        digit_str = ""

print(digits)
print(symbols)
# Out:
# [[0, [27, 30], '775'], [0, [31, 34], '651'], [0, [49, 52], '887'], [0, [56, 58], '79'], [0, [61, 64], '946'], [0, [67, 70], '921'], [0, [73, 76], '493'], [0, [81, 84], '942'], [0, [86, 89], '942'], [0, [94, 97], '151'], [0, [101, 104], '155'], [1, [6, 9], '240'], [1, [115, 118], '956'], [1, [119, 122], '549'], [1, [124, 127], '290'], [1, [134, 137], '834'], [2, [1, 4], '485'], [2, [20, 23], '437'], [2, [29, 32], '906'], [2, [41, 44], '608'], [2, [45, 48], '805'], [2, [49, 52], '725'], [2, [54, 56], '72'], [2, [61, 64], '242'], [2, [68, 71], '745'], [2, [73, 75], '61'], [2, [81, 84], '440'], [2, [129, 132], '515'], [3, [10, 13], '917'], [3, [25, 28], '146'], [3, [36, 39], '790'], [3, [89, 92], '207'], [3, [115, 118], '796'], [3, [120, 123], '116'], [3, [135, 138], '924'], [4, [0, 3], '722'], [4, [6, 9], '323'], [4, [32, 35], '410'], [4, [48, 50], '72'], [4, [52, 55], '748'], [4, [56, 59], '442'], [4, [71, 74], '384'], [4, [75, 78], '708'], [4, [93, 96], '849'], [4, [127, 130], '470'],
# ...

# %%
included = []

for digit in digits:
    # print(digit)
    start = digit[1][0]
    end = digit[1][1]
    big_l = digit[0]
    # print(start,end, l)
    included_already = False
    for l in range(big_l - 1, big_l + 2):
        for c in range(start - 1, end + 1):
            if (l, c) in symbols.keys():
                if not included_already:
                    included.append(int(digit[2]))
                    included_already = True
                    # print(digit, l,c, lines[l][c])

    # break

print(included)
print(sum(included))

# 3822541 too high
# 559957 too high
# 327190 too low
# 364627 wrong
# 553079?
# Out:
# [775, 651, 79, 946, 942, 942, 151, 240, 956, 549, 290, 834, 437, 906, 608, 805, 725, 72, 242, 745, 61, 440, 515, 917, 146, 790, 207, 796, 116, 924, 323, 410, 72, 748, 442, 384, 849, 271, 691, 4, 388, 448, 848, 370, 639, 748, 467, 921, 909, 32, 165, 452, 30, 984, 782, 711, 50, 61, 803, 524, 106, 643, 57, 433, 390, 122, 674, 379, 908, 477, 305, 876, 297, 415, 94, 378, 226, 56, 82, 167, 17, 958, 196, 380, 992, 989, 29, 301, 124, 317, 839, 191, 882, 231, 976, 469, 643, 541, 515, 498, 726, 774, 111, 378, 723, 221, 473, 752, 523, 638, 789, 353, 518, 88, 280, 297, 279, 816, 286, 975, 319, 614, 799, 503, 861, 228, 207, 838, 408, 226, 82, 268, 814, 640, 489, 719, 88, 544, 250, 115, 377, 643, 658, 651, 379, 411, 686, 202, 217, 781, 897, 630, 330, 117, 961, 61, 543, 323, 996, 603, 473, 739, 184, 511, 833, 953, 471, 464, 347, 779, 205, 694, 203, 158, 310, 449, 726, 982, 437, 259, 185, 940, 702, 465, 747, 238, 963, 687, 104, 645, 959, 497, 732, 988, 12, 417, 176, 176, 657, 566, 938, 418, 925, 28,
# ...

# %%
included = []

print(symbols)

gears = {loc: [] for loc, symbol in symbols.items() if symbol == "*"}

for digit in digits:
    # print(digit)
    start = digit[1][0]
    end = digit[1][1]
    big_l = digit[0]
    # print(start,end, l)
    included_already = False
    for l in range(big_l - 1, big_l + 2):
        for c in range(start - 1, end + 1):
            if (l, c) in gears.keys():
                if not included_already:
                    # included.append(int(digit[2]))
                    gears[(l, c)].append(int(digit[2]))
                    included_already = True
                    # print(digit, l,c, lines[l][c])


print(gears)

score = 0
for gear, list_of_parts in gears.items():
    if len(list_of_parts) == 2:
        _score = list_of_parts[0] * list_of_parts[1]
        score += _score

print(score)
# Out:
# {(1, 28): '*', (1, 34): '-', (1, 57): '$', (1, 60): '*', (1, 80): '*', (1, 88): '%', (1, 94): '+', (1, 123): '*', (2, 7): '+', (2, 38): '%', (2, 116): '*', (2, 119): '*', (2, 135): '*', (3, 20): '&', (3, 44): '*', (3, 51): '*', (3, 56): '*', (3, 67): '*', (3, 73): '*', (3, 92): '*', (3, 131): '/', (4, 10): '-', (4, 28): '/', (4, 98): '%', (5, 5): '*', (5, 32): '*', (5, 50): '-', (5, 67): '*', (5, 108): '&', (5, 117): '*', (5, 125): '&', (6, 9): '$', (6, 28): '*', (6, 39): '*', (6, 45): '*', (6, 57): '*', (6, 82): '*', (7, 15): '*', (7, 21): '*', (7, 67): '&', (7, 86): '*', (7, 135): '*', (8, 54): '&', (8, 57): '/', (8, 71): '*', (8, 98): '*', (9, 23): '/', (9, 33): '*', (9, 62): '*', (9, 84): '*', (9, 91): '+', (9, 111): '/', (9, 117): '@', (9, 135): '*', (10, 3): '*', (10, 6): '-', (10, 42): '=', (10, 47): '*', (10, 72): '+', (10, 79): '*', (10, 87): '-', (10, 131): '*', (11, 15): '*', (11, 36): '*', (11, 98): '+', (11, 125): '+', (12, 31): '*', (12, 83): '*', (12, 96): '*', (12, 10
# ...
