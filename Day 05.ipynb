# %%
import requests

year = 2023
day = 5

url = f"https://adventofcode.com/{year}/day/{day}/input"

with open("cookie.txt", "r") as file:
    session = file.read()

headers = {"cookie": f"session={session}"}

with open(f"inputs/day_{str(day).zfill(2)}_input.txt", "wb") as file:
    file.write(requests.get(url, headers=headers).content)

lines = [x.strip() for x in open(f"inputs/day_{str(day).zfill(2)}_input.txt", "r")]
print(lines[:5])
# Out:
# ['seeds: 1514493331 295250933 3793791524 105394212 828589016 654882197 658370118 49359719 4055197159 59237418 314462259 268880047 2249227634 74967914 2370414906 38444198 3291001718 85800943 2102534948 5923540', '', 'seed-to-soil map:', '3352941879 1247490906 129850502', '1738919961 2189748071 56658550']

# %%
test = """seeds: 79 14 55 13

seed-to-soil map:
50 98 2
52 50 48

soil-to-fertilizer map:
0 15 37
37 52 2
39 0 15

fertilizer-to-water map:
49 53 8
0 11 42
42 0 7
57 7 4

water-to-light map:
88 18 7
18 25 70

light-to-temperature map:
45 77 23
81 45 19
68 64 13

temperature-to-humidity map:
0 69 1
1 0 69

humidity-to-location map:
60 56 37
56 93 4""".split(
    "\n"
)

source = lines
# source = test

seed_start = [int(x) for x in source[0].split(":")[1].strip().split()]
print(seed_start)

maps = []

# this_map = {}
this_set_of_maps = []
for line in source[1:]:
    if line == "":
        maps.append(this_set_of_maps)
        #        this_map = {}
        this_set_of_maps = []
        continue
    elif ":" in line:
        #        print(line)
        pass
    else:
        this_set_of_maps.append([int(x) for x in line.split()])
maps.append(this_set_of_maps)

print(maps)

for i, seed in enumerate(seed_start):
    for set_of_maps in maps[1:]:
        done_this_map = False
        for map_ in set_of_maps:
            src_start = map_[1]
            dst_start = map_[0]
            src_end = map_[1] + map_[2]
            dst_end = map_[0] + map_[2]

            #            print(map_)
            #            print(map_[0] + map_[2], seed_start[i], map_[0])
            #            if map_[0] + map_[2] >= seed_start[i] >= map_[0]:
            if src_start <= seed_start[i] <= src_end:
                #           print("updating")
                #                print(map_)
                #                print(map_[0] - map_[1])
                seed_start[i] = seed_start[i] + dst_start - src_start
                done_this_map = True
                break
        #            print(seed_start)

        if done_this_map:
            continue

#            print(f"seed: {seed_start[1]}")
# print(seed_start)
print(min(seed_start))
# Out:
# [1514493331, 295250933, 3793791524, 105394212, 828589016, 654882197, 658370118, 49359719, 4055197159, 59237418, 314462259, 268880047, 2249227634, 74967914, 2370414906, 38444198, 3291001718, 85800943, 2102534948, 5923540]
# [[], [[3352941879, 1247490906, 129850502], [1738919961, 2189748071, 56658550], [1795578511, 292133467, 518088747], [1519757661, 1666834550, 130335907], [1650093568, 133993362, 88826393], [2813914030, 2262539545, 40894545], [2698412916, 2661705133, 115501114], [2854808575, 810222214, 437268692], [410530961, 1545057218, 121777332], [0, 242661076, 10731898], [532308293, 2303434090, 61476099], [3292077267, 1797170457, 2282798], [2313667258, 0, 133993362], [2447660620, 2410952837, 250752296], [3294360065, 253392974, 38740493], [10731898, 1377341408, 167715810], [1457582089, 2364910189, 46042648], [593784392, 3009289500, 824592362], [3333100558, 222819755, 19841321], [1418376754, 1799453255, 39205335], [1503624737, 2246406621, 16132924], [178447708, 2777206247, 232083253], [3482792381, 1838658590, 351089481]], [[3513795976, 4258851234, 36116062], [3393453635, 4148223693, 110627541], [3504081176, 3494735450, 6350258], [2671742993, 3596285367, 235915393], [991290653, 256764866, 25867175], [2907658386, 3330719253, 68855819], [3336496635, 4091266693, 56957000], [3161141476, 2536943456, 80523019], [1961696534, 304660310, 29551079], [812996514, 1560772632, 178294139], [1562163347, 2321959023, 78904062], [31289107, 1039870587, 339682886], [1520029818, 1928417376, 42133529], [3510431434, 3832200760, 3364542], [3549912038, 3272523584, 58195669], [0, 149071717, 31289107], [3608107707, 3501085708, 5732766], [503523937, 1739066771, 189350605], [3071674583, 3506818474, 89466893], [3241664495, 3996434553, 94832140], [1708133363, 454333361, 253563171], [3813493721, 3097084118, 175439466], [1991247613, 1970550905, 351408118], [3613840473, 2897430870, 199653248], [2536943456, 2762631333, 134799537], [1641067409, 244319429, 12445437], [3994753216, 3913095788, 83338765], [2976514205, 3399575072, 95160378], [1354883134, 0, 143118415], [1349131883, 2400863085, 5751251], [1498001549, 282632041, 22028269], [2342655731, 180360824, 63958605], [370971993, 1379553473, 126598642], [4149802438, 2617466475, 145164858], [1017157828, 707896532, 331974055], [692874542, 334211389, 120121972], [497570635, 143118415, 5953302], [3988933187, 3907275759, 5820029], [4078091981, 3835565302, 71710457], [1653512846, 1506152115, 54620517]], [[3053686523, 2028998994, 1241280773], [1492748555, 1562401968, 269616514], [554432178, 1000324407, 562077561], [2944878746, 3270279767, 108807777], [2501520804, 3379087544, 52288887], [1762365069, 20686928, 69653413], [2028998994, 3431376431, 472521810], [1431309984, 814973200, 3653900], [409832614, 0, 20686928], [430519542, 818627100, 123912636], [1116509739, 500172955, 314800245], [2553809691, 3903898241, 391069055], [0, 90340341, 409832614], [1434963884, 942539736, 57784671]], [[2774754469, 1598606098, 15160294], [3832622498, 1469118874, 129487224], [4125818569, 3997047227, 169148727], [1108418694, 1130695768, 196125912], [637654660, 517892123, 26551592], [2519230072, 3399515763, 135968347], [2751000257, 3126996880, 23754212], [861800165, 884077239, 88532605], [1469118874, 2566660966, 63929427], [2789914763, 3150751092, 63425583], [2853340346, 2561960449, 4700517], [1692681911, 3397592997, 1922766], [2858040863, 1773257241, 287341147], [2655198419, 2851614649, 15098309], [950332770, 972609844, 158085924], [591049922, 471287385, 46604738], [3482333989, 3849276196, 108901632], [1694604677, 1613766392, 159490849], [3591235621, 3958177828, 38869399], [3630105020, 4166195954, 128771342], [3205039781, 3535484110, 277294208], [2706794606, 2060598388, 44205651], [386607659, 544443715, 110595292], [3962109722, 2540862463, 21097986], [697311924, 0, 92263281], [558450415, 404456802, 11447837], [2409200012, 3214176675, 110030060], [569898252, 862925569, 21151670], [1354525884, 415904639, 55382746], [789575205, 790700609, 72224960], [3832262624, 2690248164, 359874], [163757080, 181606223, 222850579], [1533048301, 2967363270, 159633610], [497202951, 784452458, 6248151], [2670296728, 3812778318, 36497878], [3145382010, 2630590393, 59657771], [1854095 ...
# 579439039

# %%
test = """seeds: 79 14 55 13

seed-to-soil map:
50 98 2
52 50 48

soil-to-fertilizer map:
0 15 37
37 52 2
39 0 15

fertilizer-to-water map:
49 53 8
0 11 42
42 0 7
57 7 4

water-to-light map:
88 18 7
18 25 70

light-to-temperature map:
45 77 23
81 45 19
68 64 13

temperature-to-humidity map:
0 69 1
1 0 69

humidity-to-location map:
60 56 37
56 93 4""".split(
    "\n"
)

source = lines
# source = test

seed_start = [int(x) for x in source[0].split(":")[1].strip().split()]
# print(seed_start)

seed_start_ranges = []

for i in range(0, len(seed_start), 2):
    seed_start_ranges.append([seed_start[i], seed_start[i] + seed_start[i + 1] - 1])

print(seed_start_ranges)

maps = []

this_set_of_maps = []
for line in source[1:]:
    if line == "":
        maps.append(this_set_of_maps)
        this_set_of_maps = []
        continue
    elif ":" in line:
        pass
    else:
        map_ = [int(x) for x in line.split()]
        src_start = map_[1]
        src_end = map_[1] + map_[2]
        dst_start = map_[0]
        shift = dst_start - src_start

        this_set_of_maps.append([[src_start, src_end], shift])

maps.append(this_set_of_maps)

for set_of_maps in maps[1:]:
    new_seed_ranges = []
    to_remove_ranges = []
    for i, seed in enumerate(seed_start_ranges):
        for map_ in set_of_maps:
            map_st = map_[0][0]
            map_end = map_[0][1]
            shift = map_[1]

            # totally outside range right
            if map_end < seed[0]:
                pass
            # totally outside rnage left
            elif map_st > seed[1]:
                pass
            # totally inside range
            elif map_st > seed[0] and map_end < seed[1]:
                to_remove_ranges.append(seed)

                new_seed_ranges.append((seed[0], map_st - 1))
                new_seed_ranges.append((map_st + shift, map_end + shift))
                new_seed_ranges.append((map_end + 1, seed[1]))

            # map overlaps left
            elif map_st <= seed[0] and seed[0] <= map_end <= seed[1]:
                to_remove_ranges.append(seed)

                new_seed_ranges.append((seed[0] + shift, map_end + shift))
                if map_st > seed[0]:
                    new_seed_ranges.append((map_end + 1, seed[1]))

            # map overlaps right
            elif map_end >= seed[1] and seed[0] <= map_st <= seed[1]:
                to_remove_ranges.append(seed)
                if map_end < seed[1]:
                    new_seed_ranges.append((seed[0], map_st - 1))
                new_seed_ranges.append((map_st + shift, seed[1] + shift))

            elif map_st < seed[0] and map_end > seed[1]:
                to_remove_ranges.append(seed)
                new_seed_ranges.append((seed[0] + shift, seed[1] + shift))
            else:
                print(map_, seed)
                raise KeyboardInterrupt

    for x in to_remove_ranges:
        if x in seed_start_ranges:
            seed_start_ranges.remove(x)
    seed_start_ranges.extend(new_seed_ranges)

print(sorted(seed_start_ranges)[0][0])
# Out:
# [[1514493331, 1809744263], [3793791524, 3899185735], [828589016, 1483471212], [658370118, 707729836], [4055197159, 4114434576], [314462259, 583342305], [2249227634, 2324195547], [2370414906, 2408859103], [3291001718, 3376802660], [2102534948, 2108458487]]
# 7873084
